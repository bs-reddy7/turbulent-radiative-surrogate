# %% [markdown]
# # 01 — Explore TRL Data
# Initial data inspection: shapes, statistics, visualizations.

# %%
import numpy as np
import matplotlib.pyplot as plt

# TODO: load dataset
# data = np.load('data/trl2d.npz')
# print(data.files)

# %%
# TODO: visualize a sample field
# plt.imshow(data['u'][0], cmap='RdBu_r')
# plt.colorbar()
# plt.title('Sample field')
# plt.show()
